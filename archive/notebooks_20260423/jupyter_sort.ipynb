# %%
import os

folder = "D:/music/MAYBE_IIB"

files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
files_by_date = sorted(files, key=lambda f: os.path.getmtime(os.path.join(folder, f)))

print(files_by_date)
# Out:
# ['Track1_Imported_Track.wav', 'Track1_slide_extended.wav', 'Track1_slide_extended (1).wav', 'Track6_VoiceAudio.wav', 'Track9_VoiceAudio_4.wav', 'Track11_VoiceAudio.wav', 'Track12_VoiceAudio.wav', 'Track10_VoiceAudio.wav', 'Track13_VoiceAudio.wav', 'Track4_VoiceAudio_2.wav', 'Track5_VoiceAudio_4.wav', 'Track6_VoiceAudio_4.wav', 'Track9_VoiceAudio_7.wav', 'Track10_VoiceAudio_8.wav', 'Track11_VoiceAudio (1).wav', 'Track12_VoiceAudio (1).wav', 'Track13_VoiceAudio (1).wav', 'C Users iProg OneDrive Music  (1).wav', 'C Users iProg OneDrive Music .wav', 'Walking In Rain .wav', 'Track 2.wav', 'Lil_Baby_Type_Beat_x_Future_Type_Beat__Trap__Type_Beat__Melodic_Trap_Instrumental_2023_320_kbps.wav', 'Seen_it_all.wav', 'FREE_Sada_Baby_Type_Beat_X_Skilla_Baby_Type_Beat__Purge.wav', 'newshit Edit 3 Export 1.wav', 'SLIDE N  EXTENDO - Voice_Audio 4.wav', 'SLIDE N  EXTENDO - Voice_Audio (2).wav', 'Track1_slide_extended (2).wav', 'SLIDE N  EXTENDO - Voice_Audio 4 (1).wav', 'SLIDE N  EXTENDO - Voice_Audio 
# ...
